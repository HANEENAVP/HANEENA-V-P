# %% [markdown]
# # IMPORT THE LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IMPORT THE DATASET

# %%
train=pd.read_csv(r"C:\Users\hanee\Downloads\train_exit.csv")
train
# Out:
#         player_id                 name  age gender    country height  weight  \
# 0       PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1      PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2      PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3      PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4       PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
# ...           ...                  ...  ...    ...        ...    ...     ...
# 13989  PLID_10956         Viva Stepney   20      M    Uruguay    6'0  161lbs
# 13990  PLID_17290           Illa Pitre   18      F    England   5'10  165lbs
# 13991   PLID_5193    Marylouise Mosley   17      M      Japan    6'0  172lbs
# 13992  PLID_12173       Teri Escamilla   20      F    Ukraine   5'10  150lbs
# 13993    PLID_236       Darius Schuman   16      F      Chile    5'8  159lbs
#
# ...

# %%
train.shape
# Out:
# (13994, 30)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13975 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13577 non-null  object
#  7   ball_controlling_skills    13581 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13970 non-null  float64
#  11  penalties_conversion_rate  13964 non-null  float64
#  12  mental_strength            13966 non-null  float64
# ...

# %%
train.describe()
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance  \
# count  13994.000000             13581.000000   13994.000000  13994.000000
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength  \
# count    13970.000000               13964.000000     13966.000000
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
train.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
#UNIVARIATE ANALYSIS

# %%
selection_count=train['selection'].value_counts()
selection_count
# Out:
# 1    7802
# 0    6192
# Name: selection, dtype: int64

# %%
train['selection'].value_counts(normalize=True)
# Out:
# 1    0.557525
# 0    0.442475
# Name: selection, dtype: float64

# %%
sns.barplot(x=selection_count.index,y=selection_count.values)
plt.xlabel('selection')
plt.ylabel('Count')
plt.title('Distribution of selection')
plt.show()

# %%
#for categorical variables

# %%
sns.countplot(x='dedication_level', data=train)#independent variable
plt.xlabel('dedication Level')
plt.ylabel('Count')
plt.title('Distribution of dedication Level')
plt.show()

# %%
sns.countplot(x='gender', data=train)
plt.xlabel('gender')
plt.ylabel('count')
plt.title('Distribution of Gender')
plt.show()

# %%
#visualising numerical variable using boxplot

# %%
selected_cols=['body_balance','fitness_rating']
plt.figure(figsize=(10,6))
sns.boxplot(data=train[selected_cols])
plt.title('Boxplot for selected numerical columns')
plt.show()

# %%
#categorical independent variabel vs target variable 'selection'

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='gender',hue='selection',data=train)
plt.xlabel('gender')
plt.ylabel('Count')
plt.title('selection status by gender')
plt.show()

# %%
#numerical independent variable vs target variable

# %%
grouped_data = train.groupby('selection')[['matches_played', 'fitness_rating']].mean()

# Create a grouped bar plot
plt.figure(figsize=(10, 6))
grouped_data.plot(kind='bar', rot=0)
plt.xlabel('selection')
plt.ylabel('Mean')
plt.title('selection by matches played and applicant income')
plt.show()

# %%
#correlation matrix using heat map

# %%
sns.heatmap(train.corr(),annot=True)
# Out:
# C:\Users\hanee\AppData\Local\Temp\ipykernel_15904\2178954303.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # PREPROCESSING

# %%
train.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
#checking the missing values

# %%
train.isnull().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# ...

# %%
#filling the feature gender using mode

# %%
train['gender']=train['gender'].fillna(train['gender'].mode()[0])

# %%
#filling the feature coaching

# %%
coaching_uniq=train['coaching'].unique()
coaching_uniq
# Out:
# array(['Talent Hunt', 'Source', 'Academy', 'Unknown', nan], dtype=object)

# %%
train['coaching'].fillna('Unknown',inplace=True)

# %%
train['coaching'].replace({'nan':'Unknown'},inplace=True)

# %%
#filling the feature weight

# %%
train['weight']=train['weight'].fillna(train['weight'].mode()[0])

# %%
#filling the features ball_controlling_skills,jumping_skills,penalties_conversion_rate,mental_strength,shot_accuracy,behaviour_rating,fitness_rating,years_of_experience.

# %%
train['ball_controlling_skills']=train['ball_controlling_skills'].fillna(train['ball_controlling_skills'].mean())

# %%
train['jumping_skills']=train['jumping_skills'].fillna(train['jumping_skills'].mean())

# %%
train['penalties_conversion_rate']=train['penalties_conversion_rate'].fillna(train['penalties_conversion_rate'].mean())

# %%
train['mental_strength']=train['mental_strength'].fillna(train['mental_strength'].mean())

# %%
train['shot_accuracy']=train['shot_accuracy'].fillna(train['shot_accuracy'].mean())

# %%
train['behaviour_rating']=train['behaviour_rating'].fillna(train['behaviour_rating'].mean())

# %%
train['matches_played']=train['matches_played'].fillna(train['matches_played'].mean())

# %%
train['fitness_rating']=train['fitness_rating'].fillna(train['fitness_rating'].mean())

# %%
train['years_of_experience']=train['years_of_experience'].fillna(train['years_of_experience'].mean())

# %%
#filling the null values of thefeatures srtong_foot

# %%
strongfoot_uniq=train['strong_foot'].unique()
strongfoot_uniq
# Out:
# array(['Right', 'Any', 'Left', 'None', nan], dtype=object)

# %%
train['strong_foot'].replace({'None':'Any'},inplace=True)

# %%
train['strong_foot'].value_counts()
# Out:
# Right    8359
# Any      2552
# Left     2531
# Name: strong_foot, dtype: int64

# %%
train['strong_foot'].isnull().sum()
# Out:
# 552

# %%
train['strong_foot'].fillna(0,inplace=True)

# %%
weight_uniq=train['strong_foot'].unique()
weight_uniq

# %%
train.isnull().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# ...

# %%
train.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
train.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
#encoding the feature gender

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
train['gender'] = label_encoder.fit_transform(train['gender'])

# %%
dummy_gender = pd.get_dummies(train, columns=['gender'], prefix='gender')

# %%
train=pd.concat([train,dummy_gender],axis=1)
train
# Out:
#        age  gender height  weight  ball_controlling_skills  body_reflexes  \
# 0       23       1    6'2  176lbs                     77.0           58.0
# 1       18       1   5'10  148lbs                     54.0           69.0
# 2       16       0    6'2  172lbs                     34.0           43.0
# 3       27       1   5'11  165lbs                     79.0           73.0
# 4       19       0    5'8  158lbs                     47.0           61.0
# ...    ...     ...    ...     ...                      ...            ...
# 13989   20       1    6'0  161lbs                     60.0           48.0
# 13990   18       0   5'10  165lbs                     53.0           68.0
# 13991   17       1    6'0  172lbs                     56.0           73.0
# 13992   20       0   5'10  150lbs                     71.0           69.0
# 13993   16       0    5'8  159lbs                     53.0           59.0
#
#        body_balance  jumping_skills  penalties_conversion_rate  \
# ...

# %% [markdown]
# # MODELLING

# %%
# Import necessary libraries for model building
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
train.head()
# Out:
#    age  gender height  weight  ball_controlling_skills  body_reflexes  \
# 0   23       1    6'2  176lbs                     77.0           58.0
# 1   18       1   5'10  148lbs                     54.0           69.0
# 2   16       0    6'2  172lbs                     34.0           43.0
# 3   27       1   5'11  165lbs                     79.0           73.0
# 4   19       0    5'8  158lbs                     47.0           61.0
#
#    body_balance  jumping_skills  penalties_conversion_rate  mental_strength  \
# 0          47.0            59.0                       41.0             73.0
# 1          70.0            62.0                       53.0             43.0
# 2          45.0            69.0                       49.0             45.0
# 3          76.0            86.0                       81.0             80.0
# 4          74.0            57.0                       49.0             35.0
#
#    ...  strong_foot  behaviour_rating  matches_played  fitness_rating  \
# ...

# %%
X=train.drop(['player_id', 'name', 'country', 'selection', 'coaching'], axis=1, inplace=True)

# %%
y=train['selection']#target variable

# %%
# Handle 'height' column
X['height'] = X['height'].apply(lambda x: int(x.split("'")[0]) * 12 + int(x.split("'")[1]) if isinstance(x, str) and "'" in x else int(x))

# Handle 'weight' column
X['weight'] = X['weight'].apply(lambda x: int(x.split('lbs')[0]) if isinstance(x, str) and 'lbs' in x else int(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 2
#       1 # Handle 'height' column
# ----> 2 X['height'] = X['height'].apply(lambda x: int(x.split("'")[0]) * 12 + int(x.split("'")[1]) if isinstance(x, str) and "'" in x else int(x))
#       4 # Handle 'weight' column
#       5 X['weight'] = X['weight'].apply(lambda x: int(x.split('lbs')[0]) if isinstance(x, str) and 'lbs' in x else int(x))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#create and train knearest classifier

# %%
knn_model=KNeighborsClassifier()

# %%
knn_model.fit(X_train,y_train)

# %%
#make predictions on the test set

# %%
knn_predictions=knn_model.predict(X_test)

# %%
print("K-Nearest Neighbors Classifier Accuracy:", knn_accuracy)
